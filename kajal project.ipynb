# %%
import tkinter as tk
from tkinter import *
from PIL import ImageTk, Image
master = tk.Tk()
from tkinter import *
master.configure(background="blue")
Label(master, text=" Traffic Light::").grid()
frame = Frame(master)
frame.grid();
color = StringVar()
radio_red = Radiobutton(frame, text="Red", bg="red", variable=color, value="R", command=lambda:RadioChange(color.get()))
radio_red.grid(row=10, column=1)
radio_yellow = Radiobutton(frame, text="Yellow", bg="yellow", variable=color, value="Y", command=lambda:RadioChange(color.get()))               
radio_yellow.grid(row = 10, column = 2)
radio_green = Radiobutton(frame, text="Green", bg="green", variable=color, value="G", command=lambda:RadioChange(color.get()))
radio_green.grid(row = 10, column = 3)
canvas = Canvas(master, width=450, height=110, bg="black")
canvas.grid()
oval_red = canvas.create_oval(10, 10, 110, 100, fill="white")
oval_yellow = canvas.create_oval(120, 10, 220, 100, fill="white")
oval_green = canvas.create_oval(230, 10, 330, 100, fill="white")
def RadioChange(color):
    if color == 'R':
        canvas.itemconfig(oval_red, fill="red")
        canvas.itemconfig(oval_yellow, fill="white")
        canvas.itemconfig(oval_green, fill="white")
    elif color == 'Y':
        canvas.itemconfig(oval_red, fill="white")
        canvas.itemconfig(oval_yellow, fill="yellow")
        canvas.itemconfig(oval_green, fill="white")
    elif color == 'G':
        canvas.itemconfig(oval_red, fill="white")
        canvas.itemconfig(oval_yellow, fill="white")
        canvas.itemconfig(oval_green, fill="green")
    canvas.create_rectangle(3, 5, 350, 130)

def show_entry_fields(master):
    l=[]
    l.append(int(e1.get()))
    l.append(int(e2.get()))
    l.append(int(e3.get()))
    l.append(int(e4.get()))
    if(e1.get()>e2.get() and e1.get()>e3.get() and e1.get()>e4.get()):
        Label(master, text="north light green").grid()
        Label(master, text="south light green").grid()
        canvas = Canvas(master, width=110, height=110, bg="black")
        canvas.grid()
        oval_g = canvas.create_oval(10, 10, 110, 100, fill="black")
        color.set('G')
        canvas.itemconfig(oval_g, fill="green")
        
        canvas.itemconfig(oval_g, fill="green")
        Label(master, text="east light red").grid()
        Label(master, text="west light red").grid()
        canvas = Canvas(master, width=110, height=110, bg="blue")
        canvas.grid()
        oval_g = canvas.create_oval(10, 10, 110, 100, fill="blue")
        color.set('R')
        canvas.itemconfig(oval_g, fill="red")
        
        
    elif(e2.get()>e1.get() and e2.get()>e3.get() and e2.get()>e4.get()):
        Label(master, text="north light green").grid()
        Label(master, text="south light green").grid()
        canvas = Canvas(master, width=110, height=110, bg="blue")
        canvas.grid()
        oval_g = canvas.create_oval(10, 10, 110, 100, fill="blue")
        color.set('G')
        canvas.itemconfig(oval_g, fill="green")
        
        canvas.itemconfig(oval_g, fill="green")
        Label(master, text="east light red").grid()
        Label(master, text="west light red").grid()
        canvas = Canvas(master, width=110, height=110, bg="blue")
        canvas.grid()
        oval_g = canvas.create_oval(10, 10, 110, 100, fill="blue")
        color.set('R')
        canvas.itemconfig(oval_g, fill="red")

    elif(e3.get()>e1.get() and e3.get()>e2.get() and e3.get()>e4.get()):
        Label(master, text="east light green").grid()
        Label(master, text="west light green").grid()
        canvas = Canvas(master, width=110, height=110, bg="blue")
        canvas.grid()
        oval_g = canvas.create_oval(10, 10, 110, 100, fill="blue")
        color.set('G')
        canvas.itemconfig(oval_g, fill="green")
        
        canvas.itemconfig(oval_g, fill="green")
        Label(master, text="north light red").grid()
        Label(master, text="south light red").grid()
        canvas = Canvas(master, width=110, height=110, bg="blue")
        canvas.grid()
        oval_g = canvas.create_oval(10, 10, 110, 100, fill="blue")
        color.set('R')
        canvas.itemconfig(oval_g, fill="red")

    else:
        Label(master, text="east light green").grid()
        Label(master, text="west light green").grid()
        canvas = Canvas(master, width=110, height=110, bg="blue")
        canvas.grid()
        oval_g = canvas.create_oval(10, 10, 110, 100, fill="blue")
        color.set('G')
        canvas.itemconfig(oval_g, fill="green")
        
        canvas.itemconfig(oval_g, fill="green")
        Label(master, text="north light red").grid()
        Label(master, text="south light red").grid()
        canvas = Canvas(master, width=110, height=110, bg="blue")
        canvas.grid()
        oval_g = canvas.create_oval(10, 10, 110, 100, fill="blue")
        color.set('R')
        canvas.itemconfig(oval_g, fill="red")
tk.Label(master, text="Vechile in North Lane ").grid(row=1, column=3)
tk.Label(master, text="Vechile in South Lane ").grid(row=2,column=3)
tk.Label(master, text="Vechile in East Lane ").grid(row=3,column=3)
tk.Label(master, text="Vechile in West Lane").grid(row=4,column=3)
e1 = tk.Entry(master)
e2 = tk.Entry(master)
e3 = tk.Entry(master)
e4 = tk.Entry(master)
e1.grid(row=1, column=4)
e2.grid(row=2, column=4)
e3.grid(row=3, column=4)
e4.grid(row=4, column=4)
tk.Button(master,text='Show', command=lambda:show_entry_fields(master)).grid(row=4, column=1,sticky=tk.W,pady=4)
#######################################################################
############################################
#######################################################################
tk.mainloop()

# %%
from tkinter import *

class TrafficLights:

    def __init__(self):

        window = Tk()
        window.title("Traffic Light")


        frame = Frame(window)
        frame.pack()

        self.color = StringVar()

        radio_red = Radiobutton(frame, text="Red", bg="red", variable=self.color, value="G", command=self.on_RadioChange)
        radio_red.grid(row=10, column=1)

        radio_yellow = Radiobutton(frame, text="Yellow", bg="yellow", variable=self.color, value="Y", command=self.on_RadioChange)               
        radio_yellow.grid(row = 10, column = 2)

        radio_green = Radiobutton(frame, text="Green", bg="green", variable=self.color, value="G", command=self.on_RadioChange)
        radio_green.grid(row = 10, column = 3)
        self.canvas = Canvas(window, width=450, height=300, bg="white")
        self.canvas.pack()

        self.oval_red = self.canvas.create_oval(10, 10, 110, 110, fill="white")
        self.oval_yellow = self.canvas.create_oval(120, 10, 220, 110, fill="white")
        self.oval_green = self.canvas.create_oval(230, 10, 330, 110, fill="white")


        self.color.set('R')
        self.canvas.itemconfig(self.oval_red, fill="red")

        window.mainloop()

    def on_RadioChange(self):
        color = self.color.get()
        #color = 'R'
        if color == 'R':
            self.canvas.itemconfig(self.oval_red, fill="red")
            self.canvas.itemconfig(self.oval_yellow, fill="white")
            self.canvas.itemconfig(self.oval_green, fill="white")
        elif color == 'Y':
            self.canvas.itemconfig(self.oval_red, fill="white")
            self.canvas.itemconfig(self.oval_yellow, fill="yellow")
            self.canvas.itemconfig(self.oval_green, fill="white")
        elif color == 'G':
            self.canvas.itemconfig(self.oval_red, fill="white")
            self.canvas.itemconfig(self.oval_yellow, fill="white")
            self.canvas.itemconfig(self.oval_green, fill="green")

            self.canvas.create_rectangle(3, 5, 350, 130)
TrafficLights()

# %%
from tkinter import *
window = Tk()
window.title("Traffic Light")
frame = Frame(window)
frame.pack()
color = StringVar()
radio_red = Radiobutton(frame, text="Red", bg="red", variable=color, value="R", command=lambda:on_RadioChange(color.get()))
radio_red.grid(row=10, column=1)
radio_yellow = Radiobutton(frame, text="Yellow", bg="yellow", variable=color, value="Y", command=lambda:on_RadioChange(color.get()))               
radio_yellow.grid(row = 10, column = 2)
radio_green = Radiobutton(frame, text="Green", bg="green", variable=color, value="G", command=lambda:on_RadioChange(color.get()))
radio_green.grid(row = 10, column = 3)
canvas = Canvas(window, width=450, height=300, bg="white")
canvas.pack()
oval_red = canvas.create_oval(10, 10, 110, 110, fill="white")
oval_yellow = canvas.create_oval(120, 10, 220, 110, fill="white")
oval_green = canvas.create_oval(230, 10, 330, 110, fill="white")
color.set('R')
canvas.itemconfig(oval_red, fill="red")
#window.mainloop()
def on_RadioChange(color):
    #color = 'R'
    if color == 'R':
        canvas.itemconfig(oval_red, fill="red")
        canvas.itemconfig(oval_yellow, fill="white")
        canvas.itemconfig(oval_green, fill="white")
    elif color == 'Y':
        canvas.itemconfig(oval_red, fill="white")
        canvas.itemconfig(oval_yellow, fill="yellow")
        canvas.itemconfig(oval_green, fill="white")
    elif color == 'G':
        canvas.itemconfig(oval_red, fill="white")
        canvas.itemconfig(oval_yellow, fill="white")
        canvas.itemconfig(oval_green, fill="green")
    canvas.create_rectangle(3, 5, 350, 130)
window.mainloop()

# %%
from tkinter import *
root = Tk()
root.configure(background="red")

#1background_image = PhotoImage(file="D:\oad.gif")

#background = Label(root, image=background_image, bd=0)
#background.pack()

root.mainloop()
